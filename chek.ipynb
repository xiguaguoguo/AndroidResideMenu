# %% [markdown]
# <a href="https://colab.research.google.com/github/xiguaguoguo/AndroidResideMenu/blob/master/chek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
path = "/content/drive/My Drive/Colab Notebooks/open-unmix-pytorch"

os.chdir(path)
os.listdir(path)
# Out:
# ['open-unmix',
#  'LICENSE',
#  'data.py',
#  'environment-cpu-osx.yml',
#  'hubconf.py',
#  'eval.py',
#  '.gitignore',
#  'test.py',
#  'model.py',
#  'utils.py',
#  '.travis.yml',
#  'environment-gpu-linux-cuda10.yml',
#  'README.md',
#  'environment-cpu-linux.yml',
#  'CONTRIBUTING.md',
#  'Dockerfile',
#  '.github',
#  'docs',
#  'tests',
#  'musdb18',
#  '__pycache__',
#  'checkpoint',
#  '.ipynb_checkpoints',
#  'train.py']

# %%
# !pip install musdb
# Out:
# ...
#      |████████████████████████████████| 972kB 7.1MB/s
# ...

# %%
# !python train.py --model='/content/drive/MyDrive/Colab Notebooks/open-unmix-pytorch/open-unmix'
# Out:
# Using GPU: True
# Using Torchaudio:  False
# ...
# Done!
# Training Epoch:   0% 0/11 [00:00<?, ?it/s]
#   0% 0/320 [00:00<?, ?it/s]
# Training batch:   0% 0/320 [00:12<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/functional.py:581: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  /pytorch/aten/src/ATen/native/SpectralOps.cpp:639.)
#   normalized, onesided, return_complex)
#
# Training batch:   0% 1/320 [00:12<1:05:47, 12.37s/it]
# Training batch:   0% 1/320 [00:24<1:05:47, 12.37s/it]
# Training batch:   1% 2/320 [00:25<1:05:59, 12.45s/it]
# Training batch:   1% 2/320 [00:37<1:05:59, 12.45s/it]
# Training batch:   1% 3/320 [00:37<1:05:45, 12.45s/it]
# Training batch:   1% 3/320 [00:49<1:05:45, 12.45s/it]
# Training batch:   1% 4/320 [00:50<1:05:46, 12.49s/it]
# Training batch:   1% 4/320 [01:02<1:05:46, 12.49s/it]
# ...

# %%
# !/opt/bin/nvidia-smi
# Out:
# Fri Mar 19 10:48:22 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
